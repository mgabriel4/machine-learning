# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#no Jupyter Notebook colocamos o caminho absoluto de onde esta o dataset
#colocamos o 'r' antes do caminho para evitar problemas com as barras invertidas
data = pd.read_csv(r'C:\Users\maria.santos.6\OneDrive - ESPM\Documentos\GitHub\machine-learning\docs\data\AmesHousing.csv')

# %%
print('Primeiras linhas do dataset:\n')
print(data.head())
print('-- Informações do dataset:\n')
print(data.info())
print('-- Descrição estatística do dataset:\n')
print(data.describe())
# Out:
# Primeiras linhas do dataset:
#
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2   NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4   NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
#
# ...
